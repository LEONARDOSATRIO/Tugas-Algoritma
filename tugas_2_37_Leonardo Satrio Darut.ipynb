# %%
harga_risol = 5000
harga_piscok = 5000
mahasiswa_yang_beli_risol =2000
mahasiswa_yang_beli_piscok =500
print(harga_risol)
print(harga_piscok)
print(harga_risol*mahasiswa_yang_beli_risol+harga_piscok*mahasiswa_yang_beli_piscok)
# Out:
# 5000
# 5000
# 12500000

# %%
panjang_persegi_panjang_pertama = 12
lebar_persegi_panjang_pertama = 8
panjang_persegi_panjang_kedua = 10
lebar_persegi_panjang_kedua = 6
print(panjang_persegi_panjang_pertama)
print(lebar_persegi_panjang_pertama)
print(panjang_persegi_panjang_kedua)
print(lebar_persegi_panjang_kedua)
print(panjang_persegi_panjang_pertama*lebar_persegi_panjang_pertama+panjang_persegi_panjang_kedua*lebar_persegi_panjang_kedua)
# Out:
# 12
# 8
# 10
# 6
# 156

# %%
bola_warna_biru = input("jumlah bola warna biru: ")
bola_warna_hijau = input("jumlah bola warna hijau: ")
total_bola = int(bola_warna_biru) + int(bola_warna_hijau)
print("jumlah kedua bola adalah" + str(total_bola))
# Out:
# jumlah bola warna biru:  20
# jumlah bola warna hijau:  22
# jumlah kedua bola adalah42

# %%
nama_depan = 'Raschey'
nama_tengah = 'Blue'
nama_belakang = "Dejons"
print(nama_depan + nama_tengah + nama_belakang)
# Out:
# RascheyBlueDejons

# %%
bilangan_satu = 28
bilangan_dua = 34
print(bilangan_satu > bilangan_dua)
# Out:
# False
