# %%
nama = "Rio"
status = 'Mahasiswa'
institusi = 'Universitas Udayana'
print(f"{nama} adalah seorang {status} di {institusi}.")
# Out:
# Rio adalah seorang Mahasiswa di Universitas Udayana.

# %%
judul ='DAMPAK NEGATIVE GLOBAL WARMING TERHADAP IKLIM DI DUNIA'
sub_judul ='INDONESIA BERIKLIM TROPIS DAN SUBTROPIS'
print(judul[0:30])
print(sub_judul[0:-13])
# Out:
# DAMPAK NEGATIVE GLOBAL WARMING
# INDONESIA BERIKLIM TROPIS

# %%
judul = "labuan bajo merupakan objek pariwisata premimum"
print ((judul))
# Out:
# labuan bajo merupakan objek pariwisata premimum

# %%
x= 89
y= 3
print (x**y)
# Out:
# 704969

# %%
z = 90<120
print (z)
# Out:
# True

# %%
w = 38*2
x = 2**5
y = 38
z = 2**4
print (x+y < w-z and y-z > w/y and x==z)
# Out:
# False
