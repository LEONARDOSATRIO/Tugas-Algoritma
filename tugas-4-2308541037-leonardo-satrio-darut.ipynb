# %%
Bangun_datar = ['Persegi','Persegi Panjang','Segitiga','Lingkaran','Prisma','Jajargenjang','Belah Ketupat','Layang-layang']
Bangun_datar[4]= 'Trapesium'
print (Bangun_datar)
# Out:
# ['Persegi', 'Persegi Panjang', 'Segitiga', 'Lingkaran', 'Trapesium', 'Jajargenjang', 'Belah Ketupat', 'Layang-layang']

# %%
Danielle = ['Jen kamu ada buku fisika?']
Jennie = ['Iya,mau pinjem? tapi besok aja yahh']
Jennie [0]= 'yee'
print(Danielle)
print(Jennie)
# Out:
# ['Jen kamu ada buku fisika?']
# ['yee']

# %%
Bilangan = ['Real','Bulat','Asli','Cacah','Rasional','Irrasional','tak hingga']
Bilangan.remove('tak hingga')
print(Bilangan)
# Out:
# ['Real', 'Bulat', 'Asli', 'Cacah', 'Rasional', 'Irrasional']

# %%
Kalimat = ['merupakan planet terbesar ditata surya']
Kalimat.insert(0,'Jupiter')
print(Kalimat)
# Out:
# ['Jupiter', 'merupakan planet terbesar ditata surya']

# %%
Hari = ['Senin','Selasa','Rabu','Kamis','Jumat','Sabtu','Minggu']
h = 2
while h < len(Hari):
    print(Hari[h])
    h+=1
# Out:
# Rabu
# Kamis
# Jumat
# Sabtu
# Minggu

# %%
Planet = ['Merkurius','Venus','Bumi','Mars','Jupiter','Saturnus','Uranus','Neptunus']
p = 4
while p < len(Planet):
    print (Planet[p])
    p+=3
# Out:
# Jupiter
# Neptunus
