# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#harga makanan di warung_37
print('LIST HARGA MAKANAN DI WARUNG 37')
for isi_37 in range(15000,22000,1000):
    print(isi_37)
    print('rupiah')
# Out:
# LIST HARGA MAKANAN DI WARUNG 37
# 15000
# rupiah
# 16000
# rupiah
# 17000
# rupiah
# 18000
# rupiah
# 19000
# rupiah
# 20000
# rupiah
# 21000
# rupiah

# %%
bilangan_37 = range(15)
print(bilangan_37)
for isi_37 in bilangan_37:
    print('angka_37')
    print(isi_37)
# Out:
# range(0, 15)
# angka_37
# 0
# angka_37
# 1
# angka_37
# 2
# angka_37
# 3
# angka_37
# 4
# angka_37
# 5
# angka_37
# 6
# angka_37
# 7
# angka_37
# 8
# angka_37
# 9
# angka_37
# 10
# angka_37
# 11
# angka_37
# 12
# angka_37
# 13
# angka_37
# 14

# %%
Matriks_pertama_37 = [
[1, 3, 5, 7],
[2, 4, 6, 8]]

Matriks_kedua_37 = [
[2, 3, 5, 7],
[3, 6, 9, 12]]

Matriks_ketiga_37 = [
[4, 8, 12, 16],
[5, 10, 15, 20]
]
print('matriks_1_37')
print(Matriks_pertama_37)
print('matriks_2_37')
print(Matriks_kedua_37)
print('matriks_3_37')
print(Matriks_ketiga_37)
# Out:
# matriks_1_37
# [[1, 3, 5, 7], [2, 4, 6, 8]]
# matriks_2_37
# [[2, 3, 5, 7], [3, 6, 9, 12]]
# matriks_3_37
# [[4, 8, 12, 16], [5, 10, 15, 20]]

# %%
print('matriks_1_37')
print (Matriks_pertama_37 [0][2])
print('matriks_2_37')
print (Matriks_kedua_37 [1][3])
print('matriks_3_37')
print (Matriks_ketiga_37 [1][1])
# Out:
# matriks_1_37
# 5
# matriks_2_37
# 12
# matriks_3_37
# 10

# %%
Matriks_pertama_37  [1][1] = 4
print (Matriks_pertama_37 [1][1])
Matriks_kedua_37    [0][3]= 7
print(Matriks_kedua_37 [0][3])
Matriks_ketiga_37   [0][2] = 11
print(Matriks_ketiga_37 [0] [2])
# Out:
# 4
# 7
# 11

# %%
Matriks_pertama_37
# Out:
# [[1, 3, 5, 7], [2, 4, 6, 8]]

# %%
for baris_37 in Matriks_pertama_37:
    print(baris_37)
    print('matriks_1_37')
    for kolom_37 in baris_37:
        print(kolom_37)


for baris_37 in Matriks_kedua_37: 
    print(baris_37)
    print('matriks_2_37')
    for kolom_37 in baris_37:
        print(kolom_37)

        
for baris_37 in Matriks_ketiga_37:
    print(baris_37)
    print('matriks_3_37')
    for kolom in baris_37:
        print(kolom_37)
# Out:
# [1, 3, 5, 7]
# matriks_1_37
# 1
# 3
# 5
# 7
# [2, 4, 6, 8]
# matriks_1_37
# 2
# 4
# 6
# 8
# [2, 3, 5, 7]
# matriks_2_37
# 2
# 3
# 5
# 7
# [3, 6, 9, 12]
# matriks_2_37
# 3
# 6
# 9
# 12
# [4, 8, 12, 16]
# matriks_3_37
# 12
# 12
# 12
# 12
# [5, 10, 15, 20]
# matriks_3_37
# 12
# 12
# 12
# 12

# %%
print('DAFTAR BILANGAN GANJIL < 11')

Bilangan_ganjil_37 = (1, 3, 5, 7, 9)
print('Bilangan_ganjil_pertama_37')
print(Bilangan_ganjil_37[0])
print('Bilangan_ganjil_kedua_37')
print(Bilangan_ganjil_37[1])
print('Bilangan_ganjil_ketiga_37')
print(Bilangan_ganjil_37[2])
print('Bilangan_ganjil_keempat_37')
print(Bilangan_ganjil_37[3])
print('Bilangan_ganjil_kelima_37')
print(Bilangan_ganjil_37[4])
# Out:
# DAFTAR BILANGAN GANJIL < 11
# Bilangan_ganjil_pertama_37
# 1
# Bilangan_ganjil_kedua_37
# 3
# Bilangan_ganjil_ketiga_37
# 5
# Bilangan_ganjil_keempat_37
# 7
# Bilangan_ganjil_kelima_37
# 9

# %%
print('BILANGAN GANJIL > 1 DAN < 9')
print (Bilangan_ganjil_37 [1:4])
# Out:
# BILANGAN GANJIL > 1 DAN < 9
# (3, 5, 7)

# %%
print('BILANGAN NEGATIF')
print('List bilangan negatif_37')
Bilangan_bulat_37 = (2, -3, -4, -5, -6, -7, 8)
for isi in Bilangan_bulat_37 [1:6]:
    print(isi)
# Out:
# BILANGAN NEGATIF
# List bilangan negatif_37
# -3
# -4
# -5
# -6
# -7

# %%
Nama_mahasiswa_37 = {
    "Nama":"Damian",
    "Tahun Lahir": 2008,
    "Hobby": "Bermain alat musik",
    "Alamat_Tempat_Tinggal": "Jalan kota Bandung 13"
    
}
print ( Nama_mahasiswa_37["Nama"])
print ( Nama_mahasiswa_37.get("Tahun Lahir"))
print ( Nama_mahasiswa_37["Hobby"])
print ( Nama_mahasiswa_37["Alamat_Tempat_Tinggal"])
print ( Nama_mahasiswa_37.get("Nama_Panggilan"))
# Out:
# Damian
# 2008
# Bermain alat musik
# Jalan kota Bandung 13
# None

# %%
def tegangan_listrik (kuat_arus,hambatan):
    tegangan = kuat_arus*hambatan
    print (tegangan)
def tegangan_listrik (kuat_arus,hambatan):
    tegangan = kuat_arus*hambatan
    return tegangan
tegangan_listrik (16,10)
print (16*10)
# Out:
# 160
