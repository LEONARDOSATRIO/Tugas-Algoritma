# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# Menentukan persamaan kuadrat jika diketahui akar-akarnya

import numpy as np

# Definisikan akar-akar
r1_37 = 1
r2_37 = 3

# Hitung koefisien b dan c
b_37 = -(r1_37 + r2_37)
c_37 = r1_37 * r2_37

# Buat persamaan kuadrat
a_37 = 1
persamaan = f'{a_37}x^2 {b_37}x {c_37}'

# Tampilkan persamaan kuadrat
print(f'Persamaan kuadrat adalah {persamaan}')
# Out:
# Persamaan kuadrat adalah 1x^2 -4x 3

# %%
# Menentukan grafik fungsi kuadrat
import matplotlib.pyplot as plt
import numpy as np

akar1_37 = float(input('=> Nilai akar 1 dari persamaan kuadrat adalah'))
akar2_37 = float(input('=> Nilai akar 2 dari persamaan kuadrat adalah'))

# Menghitung nilai b dan c
b_37 = -(akar1_37 + akar2_37)
c_37 = akar1_37 * akar2_37
a_37 = 1  # nilai a default adalah 1

# Tampilkan hasil
print("Persamaan kuadrat adalah: x^2 {}{}x + {} = 0".format('' if b_37 >= 0 else '-', b_37, c_37))

# Definisikan fungsi quadratic equation
def quadratic_equation(a, b, c, x):
    return a * x**2 + b * x + c

# Menghitung persamaan kuadratnya
x_37 = np.linspace(-10, 10, 400)
y_37 = quadratic_equation(a_37, b_37, c_37, x_37)

# Plot grafik
plt.plot(x_37, y_37)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafik Fungsi Kuadrat')
plt.grid(True)
plt.show()
# Out:
# => Nilai akar 1 dari persamaan kuadrat adalah 2
# => Nilai akar 2 dari persamaan kuadrat adalah 4
# Persamaan kuadrat adalah: x^2 --6.0x + 8.0 = 0

# %%
import matplotlib.pyplot as plt
import numpy as np

akar1_37 = float(input('=> Nilai akar 1 dari persamaan kuadrat adalah: '))
akar2_37 = float(input('=> Nilai akar 2 dari persamaan kuadrat adalah: '))

# Mendefinisikan variabel x sebagai array numerik
x = np.linspace(-10, 10, 400)  # Definisikan range x dari -10 hingga 10 dengan 400 titik

# Mendefinisikan koefisien persamaan kuadrat
a_37 = 1
b_37 = akar1_37 + akar2_37
c_37 = akar1_37 * akar2_37

# Menghitung nilai y sesuai dengan fungsi kuadrat
y1_37 = a_37 * x**2 + b_37 * x + c_37

# Menampilkan grafik fungsi kuadrat
plt.plot(x, y1_37, label='Persamaan Kuadrat')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafik Fungsi Kuadrat')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# => Nilai akar 1 dari persamaan kuadrat adalah:  5
# => Nilai akar 2 dari persamaan kuadrat adalah:  7

# %%
# Titik puncak dan sumbu simetri
# Input nilai a, b, dan c dari persamaan kuadrat
a_37 = float(input("Masukkan nilai a: "))
b_37 = float(input("Masukkan nilai b: "))
c_37 = float(input("Masukkan nilai c: "))

# Hitung titik puncak persamaan kuadrat
x_tengah = -b_37 / (2 * a_37)
y_tengah = a_37 * (x_tengah ** 2) + b_37 * x_tengah + c_37

# Tampilkan hasil
print("Titik puncak persamaan kuadrat adalah: (", x_tengah, ",", y_tengah, ")\n")
print("Sumbu simetri persamaan kuadrat adalah: x =", x_tengah)
# Out:
# Masukkan nilai a:  4
# Masukkan nilai b:  6
# Masukkan nilai c:  3
# Titik puncak persamaan kuadrat adalah: ( -0.75 , 0.75 )
#
# Sumbu simetri persamaan kuadrat adalah: x = -0.75

# %%
# Titik puncak dan sumbu simetri
import matplotlib.pyplot as plt
import numpy as np
# Input nilai a, b, dan c dari persamaan kuadrat
a_37 = float(input("Masukkan nilai a: "))
b_37 = float(input("Masukkan nilai b: "))
c_37 = float(input("Masukkan nilai c: "))

# Hitung titik puncak persamaan kuadrat
x_tengah = -b_37 / (2 * a_37)
y_tengah = a_37 * (x_tengah ** 2) + b_37 * x_tengah + c_37

# Tampilkan hasil
print("Titik puncak persamaan kuadrat adalah: (", x_tengah, ",", y_tengah, ")\n")
print("Sumbu simetri persamaan kuadrat adalah: x =", x_tengah)



x = np.linspace(-10, 10, 400)
y = a_37 * x**2 + b_37 * x + c_37

plt.plot(x, y)
plt.title('Grafik Persamaan Kuadrat')
plt.xlabel('x_37')
plt.ylabel('y_37')
plt.show()
# Out:
# Masukkan nilai a:  2
# Masukkan nilai b:  4
# Masukkan nilai c:  8
# Titik puncak persamaan kuadrat adalah: ( -1.0 , 6.0 )
#
# Sumbu simetri persamaan kuadrat adalah: x = -1.0

# %%
## Menentukan grafik fungsi kuadrat
import matplotlib.pyplot as plt
import numpy as np
akar1_37 = float(input('=> Nilai akar 1 dari persamaan kuadrat adalah'))
akar2_37 = float(input('=> Nilai akar 2 dari persamaan kuadrat adalah'))
# Menghitung nilai b dan c
b = akar1_37 + akar2_37
c = akar1_37 * akar2_37
# Tampilkan hasil
print("Persamaan kuadrat adalah: {}^2 {}{}x + {} = 0".format(x, ' ' if b >= 0 else '', -b, c))

#menghitung persamaan kuadratnya
y1_37 = x**2 + b * x + c
x_37 = np.linspace(-5, 5, 200)
y_37 = quadratic_equation(a_37, b_37, c_37, x_37)


# Menentukan grafiknya
plt.plot(x_37, y_37)
plt.xlabel('x_37')
plt.ylabel('y_37')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'pink', linestyle = '--', linewidth = 0.5)
plt.title('Grafik ax^2 + bx + c')
plt.show()
# Out:
# => Nilai akar 1 dari persamaan kuadrat adalah 2
# => Nilai akar 2 dari persamaan kuadrat adalah 1
# Persamaan kuadrat adalah: -1.0^2  -3.0x + 2.0 = 0

# %%
# Menentukan posisi titik puncak
import numpy as np
import matplotlib.pyplot as plt

# Input nilai a, b, dan c dari persamaan kuadrat
a_37 = float(input("Masukkan nilai a_37: "))
b_37 = float(input("Masukkan nilai b_37: "))
c_37 = float(input("Masukkan nilai c_37: "))

# Hitung titik puncak
x_37 = -b_37 / (2 * a_37)
y_37 = a_37 * (x_37 ** 2) + b_37 * x_37 + c_37

# Tampilkan hasil
print("Posisi titik puncak adalah: (", x_37, ",", y_37, ")")

# Gambar grafik persamaan kuadrat
x_37 = np.linspace(-10, 10, 100)
y_37 = a_37 * (x ** 2) + b_37 * x + c-37
plt.plot(x_37, y_37)
plt.xlabel('x_37')
plt.ylabel('y_37')
plt.title('Grafik Persamaan Kuadrat')
plt.grid(True)
plt.show()
# Out:
# Masukkan nilai a_37:  3
# Masukkan nilai b_37:  2
# Masukkan nilai c_37:  6
# Posisi titik puncak adalah: ( -0.3333333333333333 , 5.666666666666667 )

# %%
import matplotlib.pyplot as plt
import numpy as np

# Masukkan nilai koefisien
a = 1
b = 2
c = 3

# Hitung posisi titik puncak
x = -b / (2*a)

# Buat array x dan y
x_values = np.linspace(-5, 5, 100)
y_values = a*x_values**2 + b*x_values + c

# Gambar persamaan kuadrat dan titik puncak
plt.plot(x_values, y_values, label='y = ax^2 + bx + c')
plt.plot(x, a*x**2 + b*x + c, 'ro', label='Vertex')

# Tambahkan legenda
plt.legend()

# Tambahkan label pada sumbu x dan y
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
# Tampilkan grafik
plt.show()

# Periksa posisi titik puncak pada sumbu y
if x < 0:
    print("Titik puncak berada pada sumbu y sebelah kiri atau maksimum.")
else:
    print("Titik puncak berada pada sumbu y sebelah kanan atau minimum.")
# Out:
# Titik puncak berada pada sumbu y sebelah kiri atau maksimum.

# %%
# menentukan kode grafik kondisi parabola memotong sumbu y positif, potong sumbu y di pusat(0,0)
# Input nilai a, b, dan c dari persamaan kuadrat
import numpy as np
import matplotlib.pyplot as plt

a = 1
b = 0
c = 0

# Menghitung persamaan kuadratnya
x = np.linspace(-10, 10, 100)
y = a * x**2 + b * x + c

# Menggambar grafik persamaan kuadrat
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Grafik Persamaan Kuadrat')
plt.grid(True)
plt.show()

# %%
# Menentukan akar persamaan kuadrat yang dilihat dari diskriminannya
import numpy as np
# Persamaan kuadrat pertama untuk koefisien a,b,c
a1_37 = 1
b1_37 = -4
c1_37 = 3

# Persamaan kuadrat kedua untuk koefisien a,b,c
a2_37 = 2
b2_37 = 4
c2_37 = 3


# Persamaan kuadrat ketiga untuk koefisien a,b,c
a1_37 = 3
b1_37 = -2
c1_37 = 5



# Fungsi untuk menentukan jenis akar berdasarkan diskriminan
def jenis_akar(a1_37, b1_37, c1_37):
    # Hitung diskriminan persamaan kuadrat pertama
    discriminant = b1_37**2 - 4*a1_37*c1_37
def jenis_akar(a2_37, b2_37, c2_37):  
    # Hitung diskriminan persamaan kuadrat Kedua
    discriminant = b2_37**2 - 4*a2_37*c2_37
def jenis_akar(a3_37, b3_37, c3_37):   
    # Hitung diskriminan persamaan kuadrat ketiga
    discriminant = b3_37**2 - 4*a3_37*c3_37
    
    # Cek nilai diskriminan
    if discriminant > 0:
        return "Akar Real dan Berbeda"
    elif discriminant == 0:
        return "Akar Real dan Sama"
    else:
        return "Akar Imajiner"

# untuk persamaan kuadrat pertama
for idx, (a1_37, b1_37, c1_37) in enumerate(persamaan_kuadrat):
    print(f"Persamaan kuadrat {idx + 1}: {a1_37}x^2 + {b1_37}x + {c1_37}")
    print("Diskriminan:", b1_37**2 - 4*a1_37*c1_37)
    print("Jenis Akar:", jenis_akar(a1_37, b1_37, c1_37))
    print()

# untuk persamaan kuadrat kedua
for idx, (a1_37, b1_37, c1_37) in enumerate(persamaan_kuadrat):
    print(f"Persamaan kuadrat {idx + 1}: {a2_37}x^2 + {b2_37}x + {c2_37}")
    print("Diskriminan:", b2_37**2 - 4*a2_37*c2_37)
    print("Jenis Akar:", jenis_akar(a2_37, b2_37, c2_37))
    print()

    # untuk persamaan kuadrat ketiga
for idx, (a3_37, b3_37, c3_37) in enumerate(persamaan_kuadrat):
    print(f"Persamaan kuadrat {idx + 1}: {a3_37}x^2 + {b3_37}x + {c3_37}")
    print("Diskriminan:", b3_37**2 - 4*a3_37*c3_37)
    print("Jenis Akar:", jenis_akar(a3_37, b3_37, c3_37))
    print()
# Out:
# Persamaan kuadrat 1: 1x^2 + -3x + 2
# Diskriminan: 1
# Jenis Akar: Akar Real dan Berbeda
#
# Persamaan kuadrat 2: 1x^2 + 2x + 1
# Diskriminan: 0
# Jenis Akar: Akar Real dan Sama
#
# Persamaan kuadrat 3: 1x^2 + 4x + 5
# Diskriminan: -4
# Jenis Akar: Akar Imajiner
#
# Persamaan kuadrat 1: 2x^2 + 4x + 3
# Diskriminan: -8
# Jenis Akar: Akar Imajiner
#
# Persamaan kuadrat 2: 2x^2 + 4x + 3
# Diskriminan: -8
# Jenis Akar: Akar Imajiner
#
# Persamaan kuadrat 3: 2x^2 + 4x + 3
# Diskriminan: -8
# Jenis Akar: Akar Imajiner
#
# Persamaan kuadrat 1: 1x^2 + -3x + 2
# Diskriminan: 1
# Jenis Akar: Akar Real dan Berbeda
#
# Persamaan kuadrat 2: 1x^2 + 2x + 1
# Diskriminan: 0
# Jenis Akar: Akar Real dan Sama
#
# Persamaan kuadrat 3: 1x^2 + 4x + 5
# Diskriminan: -4
# Jenis Akar: Akar Imajiner

# %%
# Persamaan kuadrat dengan rumus ABC
import numpy as np

# Fungsi untuk menentukan persamaan kuadrat dengan rumus ABC
def persamaan_kuadrat_ABC(a, b, c):
    # Hitung koefisien a, b, dan c
    A_37 = b_37**2 - 4*a_37*c_37
    B_37 = -2*b
    C_37 = A_37/(4*a_37)
    
    return f"Persamaan kuadrat: {a_37}(x - ({-B_37/(2*a_37)}))^2 + {C_37}"

# Contoh penggunaan fungsi untuk beberapa koefisien a, b, dan c
koefisien = [(1, -3, 2), (1, 2, 1), (1, 4, 5)]

for idx, (a_37, b_37, c_37) in enumerate(koefisien):
    print(f"Persamaan kuadrat ABC {idx + 1}:")
    print("Koefisien a_37:", a_37)
    print("Koefisien b_37:", b_37)
    print("Koefisien c_37:", c_37)
    print(persamaan_kuadrat_ABC(a_37, b_37, c_37))
    print()
# Out:
# Persamaan kuadrat ABC 1:
# Koefisien a_37: 1
# Koefisien b_37: -3
# Koefisien c_37: 2
# Persamaan kuadrat: 1(x - (-3.0))^2 + 0.25
#
# Persamaan kuadrat ABC 2:
# Koefisien a_37: 1
# Koefisien b_37: 2
# Koefisien c_37: 1
# Persamaan kuadrat: 1(x - (2.0))^2 + 0.0
#
# Persamaan kuadrat ABC 3:
# Koefisien a_37: 1
# Koefisien b_37: 4
# Koefisien c_37: 5
# Persamaan kuadrat: 1(x - (4.0))^2 + -1.0

# %%
# Persamaan kuadrat baru jika diketahui akar-akarnya
def persamaan_kuadrat_dari_akar(r1_37, r2_37):
    a_37 = 1  
    b_37 = - (r1_37 + r2_37)  
    c_37 = r1_37 * r2_37 

    # Mencetak persamaan kuadrat
    print(f"Persamaan kuadrat: {a_37}(x - {r1_37})(x - {r2_37}) = 0")
    print(f"Atau bisa ditulis sebagai: {a_37}x^2 + {b_37}x + {c_37} = 0")

# Input akar-akar
akar1_37 = float(input("Masukkan nilai akar pertama: "))
akar2_37 = float(input("Masukkan nilai akar kedua: "))

# Memanggil fungsi untuk membuat persamaan kuadrat baru dari akar-akarnya
persamaan_kuadrat_dari_akar(akar1_37, akar2_37)
# Out:
# Masukkan nilai akar pertama:  6
# Masukkan nilai akar kedua:  3
# Persamaan kuadrat: 1(x - 6.0)(x - 3.0) = 0
# Atau bisa ditulis sebagai: 1x^2 + -9.0x + 18.0 = 0
